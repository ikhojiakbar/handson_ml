# %% [markdown]
# # Regression

# %%
from sklearn.tree import DecisionTreeRegressor

tree_reg = DecisionTreeRegressor(max_depth=2)
tree_reg.fit(X, y)

# %% [markdown]
# * Cost Function = MSE
# * Value = Mean returned by node samples (predicts a value)
# * Feature K could be used many times in depth stages (e.g.: X1 feature)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# * Horizontal lines are averaged predicting target values
# * Vertical lines are splitting nodes by feature K (X1)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Regularization
# * Hyperparameters to regularize the model
# * 1. `max_depth`
# * 2. `min_samples_leaf`

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Instability (limitations)
# * Orthogonal decision boundaries (perpendicular to split feature K)

# %% [markdown]
# ![image.png](attachment:image.png)
